# %%
from lib.dataset.cones import CONESDetection

# %%
cones = CONESDetection('../data/cones-all/', ['cones_all'])
# Out:
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!

# %%
for i, (im, gt) in enumerate(cones):
    print(gt)
    if i > 500:
        break
# Out:
# [[192. 131. 205. 157.   2.]
#  [229. 112. 239. 128.   2.]
#  [160. 114. 169. 130.   2.]
#  [ 50. 131.  63. 153.   2.]
#  [208. 111. 216. 125.   2.]
#  [ 86. 112.  92. 127.   1.]
#  [209. 101. 216. 114.   1.]
#  [309.  95. 315. 108.   1.]
#  [396.  94. 404. 108.   1.]
#  [437.  98. 447. 115.   1.]
#  [484. 114. 501. 140.   1.]
#  [607. 165. 638. 218.   1.]]
# [[  1. 158.  17. 191.   2.]
#  [  8. 172.  32. 210.   2.]
#  [ 62. 124.  75. 144.   1.]
#  [218. 113. 231. 133.   1.]
#  [358. 112. 374. 136.   1.]
#  [446. 126. 469. 156.   1.]]
# [[313. 172. 346. 229.   1.]
#  [109. 125. 126. 151.   1.]
#  [ 90. 113.  99. 131.   1.]
#  [ 72. 110.  79. 121.   1.]
#  [ 39. 110.  43. 118.   1.]]
# [[500. 126. 521. 158.   1.]
#  [443.  99. 454. 115.   1.]
#  [393.  91. 400. 102.   1.]
#  [342.  89. 346.  97.   1.]
#  [306.  88. 311.  96.   1.]
#  [315.  84. 319.  91.   1.]
#  [299.  86. 303.  93.   1.]
#  [200. 132. 215. 159.   2.]
#  [267. 107. 277. 121.   2.]
#  [268.  97. 274. 108.   2.]
# ...

# %%
from lib.dataset.voc import VOCDetection

# %%
voc = VOCDetection('/home/lcsfrey/data/VOCdevkit', [['2007', 'trainval']], )

# %%
for i, (im, gt) in enumerate(voc):
    print(gt)
    if i > 500:
        break
# Out:
# [[262. 210. 323. 338.   9.]
#  [164. 263. 252. 371.   9.]
#  [  4. 243.  66. 373.   9.]
#  [240. 193. 294. 298.   9.]
#  [276. 185. 311. 219.   9.]]
# [[140.  49. 499. 329.   7.]]
# [[ 68. 171. 269. 329.  13.]
#  [149. 140. 228. 283.  15.]
#  [284. 200. 326. 330.  15.]
#  [257. 197. 296. 328.  15.]]
# [[155.  96. 350. 269.   7.]]
# [[ 91.  71. 304. 472.   2.]]
# [[184.  61. 278. 198.  15.]
#  [ 89.  77. 402. 335.  13.]]
# [[230.  87. 482. 255.   8.]
#  [ 10. 112. 265. 258.   8.]]
# [[ 32. 147. 370. 415.   7.]]
# [[  0. 234. 181. 387.  12.]
#  [209.  35. 335. 481.  15.]
#  [ 45.  81. 169. 364.  15.]
#  [ 10. 180. 141. 418.  15.]]
# [[  8. 229. 244. 499.   2.]
#  [229. 219. 333. 499.   2.]
#  [  1. 177.  89. 499.   2.]
#  [  1.   0. 116. 368.  15.]
#  [  2.   1. 242. 461.  15.]
#  [224.   0. 333. 485.  15.]]
# [[195. 164. 488. 246.  19.]]
# [[ 89. 124. 336. 211.   7.]]
# [[ 35. 204. 179. 288.   2.]
#  [ 50. 159. 149. 291.  15.]
#  [294. 137. 449. 289.  15.]]
# ...
